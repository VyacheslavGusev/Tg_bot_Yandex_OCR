# %%
! python -m venv venv

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached aiogram-3.4.1-py3-none-any.whl.metadata (7.2 kB)
# ...
#   Using cached aiohttp-3.9.3-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# ...
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata (34 kB)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached frozenlist-1.4.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# ...
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached magic_filter-1.0.12-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached multidict-6.0.5-cp311-cp311-win_amd64.whl.metadata (4.3 kB)
# ...
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# ...

# %%
! pip freeze
# Out:
# aiofiles==23.2.1
# aiogram==3.4.1
# aiohttp==3.9.3
# aiosignal==1.3.1
# annotated-types==0.6.0
# asttokens==2.4.1
# attrs==23.2.0
# certifi==2024.2.2
# charset-normalizer==3.3.2
# colorama==0.4.6
# comm==0.2.2
# debugpy==1.8.1
# decorator==5.1.1
# et-xmlfile==1.1.0
# executing==2.0.1
# frozenlist==1.4.1
# idna==3.6
# ipykernel==6.29.4
# ipython==8.23.0
# jedi==0.19.1
# jupyter_client==8.6.1
# jupyter_core==5.7.2
# magic-filter==1.0.12
# matplotlib-inline==0.1.6
# multidict==6.0.5
# nest-asyncio==1.6.0
# numpy==1.26.4
# opencv-python==4.9.0.80
# openpyxl==3.1.2
# packaging==24.0
# pandas==2.2.1
# parso==0.8.4
# platformdirs==4.2.0
# prompt-toolkit==3.0.43
# psutil==5.9.8
# pure-eval==0.2.2
# pydantic==2.5.3
# pydantic_core==2.14.6
# Pygments==2.17.2
# PyMuPDF==1.24.1
# PyMuPDFb==1.24.1
# python-dateutil==2.9.0.post0
# pytz==2024.1
# pywin32==306
# pyzmq==25.1.2
# requests==2.31.0
# six==1.16.0
# stack-data==0.6.3
# tornado==6.4
# traitlets==5.14.2
# typing_extensions==4.11.0
# ...

# %%
! pip install PyMuPDF
# Out:
# ...
#    ---------------------------------------- 0.0/3.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.6 MB 330.3 kB/s eta 0:00:11
#     --------------------------------------- 0.1/3.6 MB 544.7 kB/s eta 0:00:07
#    -- ------------------------------------- 0.2/3.6 MB 1.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.5/3.6 MB 2.2 MB/s eta 0:00:02
#    -------- ------------------------------- 0.8/3.6 MB 3.0 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.0/3.6 MB 3.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.9/3.6 MB 5.4 MB/s eta 0:00:01
#    ------------------------- -------------- 2.3/3.6 MB 5.9 MB/s eta 0:00:01
#    -------------------------------- ------- 2.9/3.6 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  3.6/3.6 MB 7.2 MB/s eta 0:00:01
# ...
